# %% [markdown]
# **From [https://facebook.github.io/prophet/docs/quick_start.html#python-api](https://facebook.github.io/prophet/docs/quick_start.html#python-api)**
#
# ---

# %%
from prophet import Prophet
import pandas as pd

# %%
df = pd.read_csv('../../../In-class Practices/Session I-4/prophet/example_pedestrians_covid.csv')
df.head()
# Out:
#            ds      y
# 0  2017-06-02  39230
# 1  2017-06-03  35290
# 2  2017-06-04  27083
# 3  2017-06-05  28727
# 4  2017-06-06  30315

# %%
m = Prophet()
m.fit(df)
future = m.make_future_dataframe(periods=365*2)
future.tail()
# Out:
# 14:20:20 - cmdstanpy - INFO - Chain [1] start processing
# 14:20:20 - cmdstanpy - INFO - Chain [1] done processing
#              ds
# 2215 2023-06-26
# 2216 2023-06-27
# 2217 2023-06-28
# 2218 2023-06-29
# 2219 2023-06-30

# %%
forecast = m.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#              ds          yhat    yhat_lower    yhat_upper
# 2215 2023-06-26  56347.712337  25501.321406  87731.600626
# 2216 2023-06-27  57177.975849  26017.417998  88129.533643
# 2217 2023-06-28  58509.685703  28366.530366  91411.084962
# 2218 2023-06-29  59683.464841  28931.614478  91602.995381
# 2219 2023-06-30  63370.193139  32429.310494  96714.212148

# %%
import matplotlib.pyplot as plt

fig1 = m.plot(forecast)
